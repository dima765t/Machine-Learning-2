# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Load the dataset
file_path = "Project_copy.xlsx"
sheet_name = "מתקנים לפי רשויות מעודכן 25.7.2"  # Adjust based on your dataset
data = pd.read_excel(file_path, sheet_name=sheet_name)
data.head()
# Out:
#   רשות מקומית ישוב   מספר זיהוי                      סוג מתקן  \
# 0     אבו גוש  NaN  031G2308773     אולם ספורט קטן – 15x24 מ'
# 1     אבו גוש  NaN  031G3301122  אולם ספורט בינוני – 32x19 מ'
# 2     אבו גוש  NaN  031B1305253        מגרש כדורסל – 19X32 מ'
# 3     אבו גוש  NaN  031B1205740        מגרש כדורסל – 19X32 מ'
# 4     אבו גוש  NaN  031B2305241   מגרש ספורט משולב – 43X32 מ'
#
#                    שם המתקן         שכונה-רובע              רחוב מספר בית  \
# 0  אולם התעמלות ביה"ס השלום          עבדאלרחמן  עבדאלרחמן - התמר        3
# 1          אולם פיס אבו גוש  ליד תיכון אבו גוש             השלום       12
# 2   מגרש משולב כדורגל תיכון     ליד אולם ספורט             השלום       12
# 3     מגרש קטן חטיבת ביניים                NaN             השלום      NaN
# 4     מגרש משולב יסודי מרכז               מרכז        מחמוד רשיד        1
#
#       ציר X     ציר Y  ...    פנוי לפעילות גידור קיים תאורה קיימת  \
# 0  210525.0  634529.0  ...     בתיאום בלבד         כן          כן
# 1  210265.0  635399.0  ...  מבוקר ועד לילה         כן          כן
# 2  210232.0  635383.0  ...  פתוח ללא הגבלה         כן          כן
# 3  210403.0  635436.0  ...       בוקר בלבד         לא          לא
# 4  210393.0  635129.0  ...  פתוח ללא הגבלה         כן          כן
#
#   נגישות לנכים חניה לרכבים          מצב המתקן  \
# 0           כן          כן         תקין ופעיל
# 1           כן          כן         תקין ופעיל
# 2           כן          כן  פעיל וזקוק לשיפוץ
# 3           כן          כן  פעיל וזקוק לשיפוץ
# 4           כן          כן  פעיל וזקוק לשיפוץ
#
#                         מתקן תקני לתחרויות          שימוש לתחרויות רשמיות  \
# 0   תקני וכולל שירותים, מקלחות וחדר שופטים           ליגה מקומית ואיזורית
# 1   תקני וכולל שירותים, מקלחות וחדר שופטים  מתקיימות במתקן תחרויות רשמיות
# 2  המתקן אינו עומד במידות התקניות לתחרויות      אינו משמש לתחרויות רשמיות
# 3  המתקן אינו עומד במידות התקניות לתחרויות      אינו משמש לתחרויות רשמיות
# 4  המתקן אינו עומד במידות התקניות לתחרויות      אינו משמש לתחרויות רשמיות
#
#   שנת הקמה                 משרת בית ספר
# 0   2019.0                           כן
# 1   2008.0  חטיבת ביניים ותיכון אבו גוש
# 2   1994.0  חטיבת ביניים ותיכון אבו גוש
# 3   2005.0                 חטיבת ביניים
# 4   1975.0           יסודי אבו גוש מרכז
#
# [5 rows x 26 columns]

# %%
# Create a dictionary mapping Hebrew column names to English
column_name_mapping = {
    "רשות מקומית": "Municipality",
    "ישוב": "Settlement",
    "מספר זיהוי": "ID",
    "סוג מתקן": "Facility Type",
    "שם המתקן": "Facility Name",
    "שכונה-רובע": "Neighborhood",
    "רחוב": "Street",
    "מספר בית": "House Number",
    "ציר X": "X Cord",
    "ציר Y": "Y Cord",
    "גוף מפעיל המתקן": "Operator",
    'בעלי המתקן': "Owner",
    "מספר המבנים": 'Building Amount',
    'טלפון איש קשר': "Contact Phone",
    'דואל איש קשר': "Contact eMail",
    'מספר מושבים': "Seat amount",
    "פנוי לפעילות": "Availability",
    "גידור קיים": "Fencing Available",
    "תאורה קיימת": "Lighting Available",
    "נגישות לנכים": "Accessibility",
    "חניה לרכבים": "Parking Available",
    "מצב המתקן": "Facility Condition",
    "מתקן תקני לתחרויות": "Competition Standard",
    "שימוש לתחרויות רשמיות": "Official Competition Use",
    "שנת הקמה": "Year Built",
    "משרת בית ספר": "School Served"
}

# Rename the columns in the dataset
data.rename(columns=column_name_mapping, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8777 entries, 0 to 8776
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Municipality              8777 non-null   object
#  1   Settlement                294 non-null    object
#  2   ID                        8777 non-null   object
#  3   Facility Type             8777 non-null   object
#  4   Facility Name             8777 non-null   object
#  5   Neighborhood              4393 non-null   object
#  6   Street                    5408 non-null   object
#  7   House Number              3259 non-null   object
#  8   X Cord                    8771 non-null   float64
#  9   Y Cord                    8771 non-null   float64
#  10  Building Amount           3194 non-null   float64
#  11  Owner                     6302 non-null   object
#  12  Operator                  8742 non-null   object
#  13  Contact Phone             6512 non-null   object
#  14  Contact eMail             5226 non-null   object
#  15  Seat amount               1850 non-null   float64
#  16  Availability              8777 non-null   object
#  17  Fencing Available         8777 non-null   object
#  18  Lighting Available        8777 non-null   object
#  19  Accessibility             8777 non-null   object
#  20  Parking Available         8777 non-null   object
#  21  Facility Condition        8776 non-null   object
#  22  Competition Standard      7156 non-null   object
#  23  Official Competition Use  7140 non-null   object
#  24  Year Built                6739 non-null   float64
#  25  School Served             3775 non-null   object
# dtypes: float64(5), object(21)
# memory usage: 1.7+ MB

# %%
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Municipality                   0
# Settlement                  8483
# ID                             0
# Facility Type                  0
# Facility Name                  0
# Neighborhood                4384
# Street                      3369
# House Number                5518
# X Cord                         6
# Y Cord                         6
# Building Amount             5583
# Owner                       2475
# Operator                      35
# Contact Phone               2265
# Contact eMail               3551
# Seat amount                 6927
# Availability                   0
# Fencing Available              0
# Lighting Available             0
# Accessibility                  0
# Parking Available              0
# Facility Condition             1
# Competition Standard        1621
# Official Competition Use    1637
# Year Built                  2038
# School Served               5002
# dtype: int64

# %% [markdown]
# # Find and display unique values for each column
# for column in data.columns:
#     unique_values = data[column].unique()
#     print(f"Column: {column}\nUnique Values: {unique_values}\n")

# %%
availability_mapping = {
    "פתוח ללא הגבלה": "Very High",
    "מבוקר ועד לילה": "High",
    "בוקר בלבד": "Medium",
    "בתיאום בלבד": "Low",
}

data['Availability Category'] = data['Availability'].map(availability_mapping)

# %%
fencing_mapping = {
    "כן": 1,
    "לא": 0
}

data['Fencing Available Numeric'] = data['Fencing Available'].map(fencing_mapping)

# %%
lighting_mapping = {
    "כן": 1,
    "לא": 0
}

data['Lighting Available Numeric'] = data['Lighting Available'].map(lighting_mapping)

# %%
condition_mapping = {
    "תקין ופעיל": 4,
    "פעיל וזקוק לשיפוץ": 3,
    "לא פעיל": 2,
    "לא תקין ולא פעיל": 1,
    "סגור לשימוש": 0
}

data['Facility Condition Numeric'] = data['Facility Condition'].map(condition_mapping)

# %%
# Verify the newly created columns
print(data[['Availability', 'Availability Category', 
            'Fencing Available', 'Fencing Available Numeric', 
            'Lighting Available', 'Lighting Available Numeric', 
            'Facility Condition', 'Facility Condition Numeric']].head())
# Out:
#      Availability Availability Category Fencing Available  \
# 0     בתיאום בלבד                   Low                כן
# 1  מבוקר ועד לילה                  High                כן
# 2  פתוח ללא הגבלה             Very High                כן
# 3       בוקר בלבד                Medium                לא
# 4  פתוח ללא הגבלה             Very High                כן
#
#    Fencing Available Numeric Lighting Available  Lighting Available Numeric  \
# 0                          1                 כן                           1
# 1                          1                 כן                           1
# 2                          1                 כן                           1
# 3                          0                 לא                           0
# 4                          1                 כן                           1
#
#   Facility Condition  Facility Condition Numeric
# 0         תקין ופעיל                         4.0
# 1         תקין ופעיל                         4.0
# 2  פעיל וזקוק לשיפוץ                         3.0
# 3  פעיל וזקוק לשיפוץ                         3.0
# 4  פעיל וזקוק לשיפוץ                         3.0

# %%
current_year = 2025

# Calculate the age of the facility
data['Facility Age'] = current_year - data['Year Built']

# Ensure there are no negative or invalid ages
data['Facility Age'] = data['Facility Age'].apply(lambda x: x if x >= 0 else None)

# Display the first few rows to verify the new column
print(data[['Year Built', 'Facility Age']].head())
# Out:
#    Year Built  Facility Age
# 0      2019.0           6.0
# 1      2008.0          17.0
# 2      1994.0          31.0
# 3      2005.0          20.0
# 4      1975.0          50.0

# %%
# Save the dataset with updated column names
data.to_csv("processed_data.csv", index=False)
data.head()
# Out:
#   Municipality Settlement           ID                 Facility Type  \
# 0      אבו גוש        NaN  031G2308773     אולם ספורט קטן – 15x24 מ'
# 1      אבו גוש        NaN  031G3301122  אולם ספורט בינוני – 32x19 מ'
# 2      אבו גוש        NaN  031B1305253        מגרש כדורסל – 19X32 מ'
# 3      אבו גוש        NaN  031B1205740        מגרש כדורסל – 19X32 מ'
# 4      אבו גוש        NaN  031B2305241   מגרש ספורט משולב – 43X32 מ'
#
#               Facility Name       Neighborhood            Street House Number  \
# 0  אולם התעמלות ביה"ס השלום          עבדאלרחמן  עבדאלרחמן - התמר            3
# 1          אולם פיס אבו גוש  ליד תיכון אבו גוש             השלום           12
# 2   מגרש משולב כדורגל תיכון     ליד אולם ספורט             השלום           12
# 3     מגרש קטן חטיבת ביניים                NaN             השלום          NaN
# 4     מגרש משולב יסודי מרכז               מרכז        מחמוד רשיד            1
#
#      X Cord    Y Cord  ...  Facility Condition  \
# 0  210525.0  634529.0  ...          תקין ופעיל
# 1  210265.0  635399.0  ...          תקין ופעיל
# 2  210232.0  635383.0  ...   פעיל וזקוק לשיפוץ
# 3  210403.0  635436.0  ...   פעיל וזקוק לשיפוץ
# 4  210393.0  635129.0  ...   פעיל וזקוק לשיפוץ
#
#                       Competition Standard       Official Competition Use  \
# 0   תקני וכולל שירותים, מקלחות וחדר שופטים           ליגה מקומית ואיזורית
# 1   תקני וכולל שירותים, מקלחות וחדר שופטים  מתקיימות במתקן תחרויות רשמיות
# 2  המתקן אינו עומד במידות התקניות לתחרויות      אינו משמש לתחרויות רשמיות
# 3  המתקן אינו עומד במידות התקניות לתחרויות      אינו משמש לתחרויות רשמיות
# 4  המתקן אינו עומד במידות התקניות לתחרויות      אינו משמש לתחרויות רשמיות
#
#   Year Built                School Served  Availability Category  \
# 0     2019.0                           כן                    Low
# 1     2008.0  חטיבת ביניים ותיכון אבו גוש                   High
# 2     1994.0  חטיבת ביניים ותיכון אבו גוש              Very High
# 3     2005.0                 חטיבת ביניים                 Medium
# 4     1975.0           יסודי אבו גוש מרכז              Very High
#
#   Fencing Available Numeric Lighting Available Numeric  \
# 0                         1                          1
# 1                         1                          1
# 2                         1                          1
# 3                         0                          0
# 4                         1                          1
#
#   Facility Condition Numeric Facility Age
# 0                        4.0          6.0
# 1                        4.0         17.0
# 2                        3.0         31.0
# 3                        3.0         20.0
# 4                        3.0         50.0
#
# [5 rows x 31 columns]
